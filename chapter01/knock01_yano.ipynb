# %%
s = "stressed"
s[::-1]
# Out:
# 'desserts'

# %%
s = "パタトクカシー"
s[::2]
# Out:
# 'パトカー'

# %%
s_1 = "パトカー"
s_2 = "タクシー"
s = ''.join([i + j for i ,j in zip(s_1,s_2)])
s
# Out:
# 'パタトクカシーー'

# %%
s = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
s = s.replace(',','').replace('.','') 
[len(i) for i in s.split()]
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %%
s = 'Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can.'
s = s.replace('.','')
s = s.split()
idx = [1, 5, 6, 7, 8, 9, 15, 16, 19]
di = {}
for i in range(len(s)):
  if i + 1 in idx:
    di[s[i][0]] = i + 1
  else:
    di[s[i][0:2]] = i + 1

d = sorted(di.items(),key=lambda i: i[1], reverse=False)
d
# Out:
# [('H', 1),
#  ('He', 2),
#  ('Li', 3),
#  ('Be', 4),
#  ('B', 5),
#  ('C', 6),
#  ('N', 7),
#  ('O', 8),
#  ('F', 9),
#  ('Ne', 10),
#  ('Na', 11),
#  ('Mi', 12),
#  ('Al', 13),
#  ('Si', 14),
#  ('P', 15),
#  ('S', 16),
#  ('Cl', 17),
#  ('Ar', 18),
#  ('K', 19),
#  ('Ca', 20)]
